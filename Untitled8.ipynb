# %% [markdown]
# <a href="https://colab.research.google.com/github/Repezel/Tennis_model/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Repezel/Tennis_model.git

import os
os.chdir("Tennis_model")

# !ls
# Out:
# Cloning into 'Tennis_model'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), 3.77 MiB | 9.21 MiB/s, done.
# final_combined.csv

# %%
import pandas as pd

df = pd.read_csv("final_combined.csv")
df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  1968-2029       Dublin   Grass       32.0             A      19680708
# 1  1968-2029       Dublin   Grass       32.0             A      19680708
# 2  1968-2029       Dublin   Grass       32.0             A      19680708
# 3  1968-2029       Dublin   Grass       32.0             A      19680708
# 4  1968-2029       Dublin   Grass       32.0             A      19680708
#
#    match_num  winner_id  winner_seed winner_entry  ... loser_seed loser_entry  \
# 0        270     112411          NaN          NaN  ...        NaN         NaN
# 1        271     126914          NaN          NaN  ...        NaN         NaN
# 2        272     209523          NaN          NaN  ...        NaN         NaN
# 3        273     100084          NaN          NaN  ...        NaN         NaN
# 4        274     100132          NaN          NaN  ...        NaN         NaN
#
# ...

# %%
import glob

files = glob.glob("*.csv")
print(files)
# Out:
# ['final_combined.csv']

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/Repezel/Tennis_model/main/final_combined.csv"

df = pd.read_csv(url)

df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  1968-2029       Dublin   Grass       32.0             A      19680708
# 1  1968-2029       Dublin   Grass       32.0             A      19680708
# 2  1968-2029       Dublin   Grass       32.0             A      19680708
# 3  1968-2029       Dublin   Grass       32.0             A      19680708
# 4  1968-2029       Dublin   Grass       32.0             A      19680708
#
#    match_num  winner_id  winner_seed winner_entry  ... loser_seed loser_entry  \
# 0        270     112411          NaN          NaN  ...        NaN         NaN
# 1        271     126914          NaN          NaN  ...        NaN         NaN
# 2        272     209523          NaN          NaN  ...        NaN         NaN
# 3        273     100084          NaN          NaN  ...        NaN         NaN
# 4        274     100132          NaN          NaN  ...        NaN         NaN
#
# ...

# %%
df.shape
# Out:
# (194996, 26)

# %%
files = glob.glob("atp_matches_*.csv")
